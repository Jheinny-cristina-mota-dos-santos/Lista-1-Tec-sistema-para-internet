# %% [markdown]
# <a href="https://colab.research.google.com/github/Jheinny-cristina-mota-dos-santos/Lista-1-Tec-sistema-para-internet/blob/main/C%C3%A1lculo_de_Desconto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
valor = float(input("Digite o valor do produto: "))
percentual = float(input("Digite o percentual de desconto: "))

desconto = valor * percentual / 100
valor_final = valor - desconto

print("O valor final do produto é:")
print(valor_final)
# Out:
# Digite o valor do produto: 200
# Digite o percentual de desconto: 10
# O valor final do produto é:
# 180.0
