# %% [markdown]
# <a href="https://colab.research.google.com/github/Jheinny-cristina-mota-dos-santos/Lista-1-Tec-sistema-para-internet/blob/main/Convers%C3%A3o_de_Temperatura_(Celsius_%E2%86%92_Fahrenheit).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
celsius = float(input("Digite a temperatura em Celsius: "))

fahrenheit = celsius * 9/5 + 32

print("A temperatura em Fahrenheit é:")
print(fahrenheit)
# Out:
# Digite a temperatura em Celsius: 0
# A temperatura em Fahrenheit é:
# 32.0
